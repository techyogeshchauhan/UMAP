# %%
pip install umap-learn
# Out:
# Requirement already satisfied: umap-learn in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (0.5.9.post2)
# Requirement already satisfied: numpy>=1.23 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from umap-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.3.1 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from umap-learn) (1.15.3)
# Requirement already satisfied: scikit-learn>=1.6 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from umap-learn) (1.7.1)
# Requirement already satisfied: numba>=0.51.2 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from umap-learn) (0.61.2)
# Requirement already satisfied: pynndescent>=0.5 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from umap-learn) (0.5.13)
# Requirement already satisfied: tqdm in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from umap-learn) (4.67.1)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from numba>=0.51.2->umap-learn) (0.44.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from pynndescent>=0.5->umap-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from scikit-learn>=1.6->umap-learn) (3.6.0)
# Requirement already satisfied: colorama in c:\users\yc993\.conda\envs\schlorhat\lib\site-packages (from tqdm->umap-learn) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import umap
# %matplotlib inline
sns.set(style='white', context='poster', rc={'figure.figsize':(14,10)})
np.random.seed(44)
data = np.random.rand(700, 4)
fit = umap.UMAP()
# %time u = fit.fit_transform(data)
# Out:
# CPU times: total: 20 s
# Wall time: 35.8 s

# %%
plt.scatter(u[:,0], u[:,1], c=data)
plt.title('UMAP embedding of random colours');

# %% [markdown]
# Remove the dimensity

# %%
import numpy as np
import umap
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

digits = load_digits()
data = digits.data
scaler = StandardScaler()
data = scaler.fit_transform(data)

# Apply UMAP
reducer = umap.UMAP()
embedding = reducer.fit_transform(data)
plt.scatter(embedding[:, 0], embedding[:, 1], c=digits.target, cmap='Spectral', s=5)
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
plt.show()

# %%
np.random.seed(0)
n_samples = 100
n_features = 10
data = np.random.rand(n_samples, n_features)

# %%
umap_obj = umap.UMAP(n_neighbors=5, min_dist=0.3, random_state=42)

# %%
embedding = umap_obj.fit_transform(data)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1])
plt.title('UMAP Embedding')
plt.xlabel('UMAP Dimension 1')
plt.ylabel('UMAP Dimension 2')
plt.show()
